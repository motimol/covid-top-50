# %%
import requests
import pandas as pd
import json

url = "https://api.covid19api.com/summary"
response = requests.request("GET", url)
data = response.text
# data = "{" + data[data.index('"Countries"'):]
data = json.loads(data)
js_2 = json.loads(response.text)
print(js_2)
df_global = pd.json_normalize(data)
df_countries = pd.json_normalize(data["Countries"])
# Out:
# {'ID': 'a75cdc2e-86dc-453d-a76b-21689a34dce3', 'Message': '', 'Global': {'NewConfirmed': 495713, 'TotalConfirmed': 469087355, 'NewDeaths': 2120, 'TotalDeaths': 6069928, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2022-03-20T06:29:18.782Z'}, 'Countries': [{'ID': '87779783-a615-4733-9529-419c328eb17e', 'Country': 'Afghanistan', 'CountryCode': 'AF', 'Slug': 'afghanistan', 'NewConfirmed': 0, 'TotalConfirmed': 177039, 'NewDeaths': 0, 'TotalDeaths': 7652, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2022-03-20T06:29:18.782Z', 'Premium': {}}, {'ID': '19c4a343-a5b0-4da6-9a58-917795fddc18', 'Country': 'Albania', 'CountryCode': 'AL', 'Slug': 'albania', 'NewConfirmed': 0, 'TotalConfirmed': 273040, 'NewDeaths': 0, 'TotalDeaths': 3487, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2022-03-20T06:29:18.782Z', 'Premium': {}}, {'ID': '892494fb-8f3f-419a-bbbb-9f02366db868', 'Country': 'Algeria', 'CountryCode': 'DZ', 'Slug': 'algeria', 'NewConfirmed': 0, 'TotalConfirmed': 265539, 'NewDeaths': 0, 'TotalDeaths': 6871, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2022-03-20T06:29:18.782Z', 'Premium': {}}, {'ID': '614e7b85-7fec-4cb6-8e58-0008f3c2f840', 'Country': 'Andorra', 'CountryCode': 'AD', 'Slug': 'andorra', 'NewConfirmed': 0, 'TotalConfirmed': 39234, 'NewDeaths': 0, 'TotalDeaths': 153, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2022-03-20T06:29:18.782Z', 'Premium': {}}, {'ID': '08cbaef8-994c-4356-9d32-f64e4e71d8dc', 'Country': 'Angola', 'CountryCode': 'AO', 'Slug': 'angola', 'NewConfirmed': 0, 'TotalConfirmed': 99003, 'NewDeaths': 0, 'TotalDeaths': 1900, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2022-03-20T06:29:18.782Z', 'Premium': {}}, {'ID': '28597a9f-6807-4301-8c05-6589dfe94655', 'Country': 'Antarctica', 'CountryCode': 'AQ', 'Slug': 'antarctica', 'NewConfirmed': 0, 'TotalConfirmed': 11, 'NewDeaths': 0, 'TotalDeaths': 0, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2022-03-20T06:29:18.782Z', 'Premium': {}}, {'ID': '9a5e8a74-5709-455b-858e-3ab7004afd53', 'Country': 'Antigua and Barbuda', 'CountryCode': 'AG', 'Slug': 'antigua-and-barbuda', 'NewConfirmed': 0, 'TotalConfirmed': 7473, 'NewDeaths': 0, 'TotalDeaths': 135, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2022-03-20T06:29:18.782Z', 'Premium': {}}, {'ID': '8466a209-13b2-4295-91cb-1a687a5c2d3a', 'Country': 'Argentina', 'CountryCode': 'AR', 'Slug': 'argentina', 'NewConfirmed': 0, 'TotalConfirmed': 9006526, 'NewDeaths': 0, 'TotalDeaths': 127483, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2022-03-20T06:29:18.782Z', 'Premium': {}}, {'ID': 'ef8b0c8d-62b7-4533-a5c0-eb67e32c0f6b', 'Country': 'Armenia', 'CountryCode': 'AM', 'Slug': 'armenia', 'NewConfirmed': 0, 'TotalConfirmed': 422286, 'NewDeaths': 0, 'TotalDeaths': 8593, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2022-03-20T06:29:18.782Z', 'Premium': {}}, {'ID': '1c6d6a64-cee7-4e53-b592-a6c45e849aa1', 'Country': 'Australia', 'CountryCode': 'AU', 'Slug': 'australia', 'NewConfirmed': 40854, 'TotalConfirmed': 3900138, 'NewDeaths': 3, 'TotalDeaths': 5725, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2022-03-20T06:29:18.782Z', 'Premium': {}}, {'ID': 'e3e7fc69-2bfc-4bac-8f56-c7dfb49923d5', 'Country': 'Austria', 'CountryCode': 'AT', 'Slug': 'austria', 'NewConfirmed': 0, 'TotalConfirmed': 3429011, 'NewDeaths': 0, 'TotalDeaths': 15387, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2022-03-20T06:29:18.782Z', 'Premium': {}}, {'ID': '35656713-1203-449a-9ba4-27855945d159', 'Country': 'Azerbaijan', 'CountryCode': 'AZ', 'Slug': 'azerbaijan', 'NewConfirmed': 0, 'TotalConfirmed': 791404, 'NewDeaths': 0, 'TotalDeaths': 9651, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2022-03-20T06:29:18.782Z', 'Premium': {}}, {'ID': '45e7a72e-9530-459c-b46e-394b040bb949', 'Country': 'Bahamas', 'CountryCode': 'BS', 'Slug': 'bahamas', 'NewConfirmed': 0, 'TotalConfirmed': 33211, 'NewDeaths': 0, 'TotalDeaths': 777, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2022-03-20T06:29:18.782Z', 'Premium': {}}, {'ID': '0153dd6a ...

# %%
df_countries
# Out:
#                                        ID                          Country  \
# 0    87779783-a615-4733-9529-419c328eb17e                      Afghanistan
# 1    19c4a343-a5b0-4da6-9a58-917795fddc18                          Albania
# 2    892494fb-8f3f-419a-bbbb-9f02366db868                          Algeria
# 3    614e7b85-7fec-4cb6-8e58-0008f3c2f840                          Andorra
# 4    08cbaef8-994c-4356-9d32-f64e4e71d8dc                           Angola
# ..                                    ...                              ...
# 189  fe09e42c-6f42-46e9-8e1b-05eb46f3f000  Venezuela (Bolivarian Republic)
# 190  ab207792-6499-49b0-b43c-463083f6ec3a                         Viet Nam
# 191  56515319-4b46-41a5-bd5d-3b23e98ea3d2                            Yemen
# 192  cdd8a960-d375-48a5-9a32-a1993e2cc1e9                           Zambia
# 193  551bc035-4299-4a45-9155-5eacde95fb30                         Zimbabwe
#
#     CountryCode         Slug  NewConfirmed  TotalConfirmed  NewDeaths  \
# 0            AF  afghanistan             0          177039          0
# 1            AL      albania             0          273040          0
# 2            DZ      algeria             0          265539          0
# 3            AD      andorra             0           39234          0
# 4            AO       angola             0           99003          0
# ..          ...          ...           ...             ...        ...
# 189          VE    venezuela             0          519420          0
# 190          VN      vietnam             0         7791841          0
# 191          YE        yemen             0           11799          0
# 192          ZM       zambia             0          315623          0
# 193          ZW     zimbabwe             0          244452          0
#
#      TotalDeaths  NewRecovered  TotalRecovered                      Date
# 0           7652             0               0  2022-03-20T06:29:18.782Z
# 1           3487             0               0  2022-03-20T06:29:18.782Z
# 2           6871             0               0  2022-03-20T06:29:18.782Z
# 3            153             0               0  2022-03-20T06:29:18.782Z
# 4           1900             0               0  2022-03-20T06:29:18.782Z
# ..           ...           ...             ...                       ...
# 189         5666             0               0  2022-03-20T06:29:18.782Z
# 190        41817             0               0  2022-03-20T06:29:18.782Z
# 191         2140             0               0  2022-03-20T06:29:18.782Z
# 192         3962             0               0  2022-03-20T06:29:18.782Z
# 193         5426             0               0  2022-03-20T06:29:18.782Z
#
# [194 rows x 11 columns]
